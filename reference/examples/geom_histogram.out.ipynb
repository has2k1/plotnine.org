# %% [markdown]
# # Histograms

# %%
from plotnine import (
    ggplot,
    aes,
    after_stat,
    geom_histogram,
    facet_wrap,
    facet_grid,
    coord_flip,
    scale_y_continuous,
    scale_y_sqrt,
    scale_y_log10,
    scale_fill_manual,
    theme_bw,
    theme_xkcd,
)
from plotnine.data import diamonds
from mizani.formatters import percent_format

# %% [markdown]
# Visualise the distribution of a variable by dividing the x-axis into
# bins and counting the number of observations in each bin. Histograms
# display the counts with bars.
#
# You can define the number of bins (e.g. divide the data five bins) or
# define the binwidth (e.g. each bin is size 10).
#
# Distributions can be visualised as: \* count, \* normalised count, \*
# density, \* normalised density, \* scaled density as a percentage.

# %%
diamonds.head(5)
# Out:
# </div>

# %% [markdown]
# ### Basic Histogram
#
# If you create a basic histogram, you will be prompted to define the
# binwidth or number of bins.

# %%
# Gallery, distributions
(
    ggplot(diamonds, aes(x="carat"))
    + geom_histogram()
)
# Out:
# /Users/hassan/scm/python/plotnine/plotnine/stats/stat_bin.py:108: PlotnineWarning: 'stat_bin()' using 'bins = 142'. Pick better value with 'binwidth'.

# %% [markdown]
# You can define the width of the bins, by specifying the `binwidth`
# inside `geom_histogram()`.

# %%
(
    ggplot(diamonds, aes(x="carat"))
    + geom_histogram(binwidth=0.5)  # specify the binwidth
)

# %% [markdown]
# Or you can define the number of bins by specifying `bins` inside
# `geom_histogram()`. Note, the example below uses 10 bins, however you
# can’t see them all because some of the bins are too small to be
# noticeable.

# %%
(
    ggplot(diamonds, aes(x="carat"))
    + geom_histogram(bins=10)  # specify the number of bins
)

# %% [markdown]
# There are different ways to visualise the distribution, you can specify
# this using the `y` argument within `aes()`. In the example below I’m
# using the default setting: raw count with `after_stat('count')`.

# %%
(
    ggplot(
        diamonds,
        aes(
            x="carat",
            y=after_stat("count"),  # specify each bin is a count
        ),
    )
    + geom_histogram(binwidth=0.50)
)

# %% [markdown]
# You can normalise the raw count to 1 by using `after_stat('ncount')`:

# %%
(
    ggplot(
        diamonds,
        aes(
            x="carat",
            y=after_stat("ncount"),  # normalise the count to 1
        ),
    )
    + geom_histogram(binwidth=0.50)
)

# %% [markdown]
# You can display the density of points in a bin, (this is scaled to
# integrate to 1) by using `after_stat('density')`:

# %%
(
    ggplot(
        diamonds,
        aes(
            x="carat",
            y=after_stat("density"),  # density
        ),
    )
    + geom_histogram(binwidth=0.50)
)

# %% [markdown]
# The proportion of bins can be shown, in the example below the `bin=0.5`
# accounts for about ~55% of the data:

# %%
(
    ggplot(
        diamonds,
        aes(x="carat", y=after_stat("width*density")),  # show proportion
    )
    + geom_histogram(binwidth=0.5)
)

# %% [markdown]
# We can also display counts as percentages by using the
# `percent_format()` which requires the `mizani.formatters` library:

# %%
(
    ggplot(diamonds, aes(x="carat", y=after_stat("width*density")))
    + geom_histogram(binwidth=0.5)
    + scale_y_continuous(labels=percent_format())  # display labels as a percentage
)

# %% [markdown]
# Instead of using `stat` you can use `stat_bin` defined within
# `geom_histogram()`, this is useful if you want to layer a few different
# plots in the one figure.

# %%
(
    ggplot(diamonds, aes(x="carat"))
    + geom_histogram(binwidth=0.5, alpha=0.5)
    + geom_histogram(binwidth=0.2, alpha=0.5, fill="green")
)

# %% [markdown]
# You can also flip the x-y coordinates:

# %%
(
    ggplot(diamonds, aes(x="carat", y=after_stat("density")))
    + geom_histogram(binwidth=0.5)
    + coord_flip()
)

# %% [markdown]
# You can visualise counts by other variables using `fill` within `aes()`:

# %%
(
    ggplot(diamonds, aes(x="carat", y=after_stat("count"), fill="cut"))
    + geom_histogram(binwidth=0.5)
)

# %% [markdown]
# You can visualise too-small-to-see bars by transforming the y-axis
# scaling by using `scale_y_sqrt()` square-root scale or `scale_y_log10()`
# for a log-scale (similarly use `scale_x_sqrt()` and `scale_x_log10()` to
# transform the x-axis).

# %%
(
    ggplot(diamonds, aes(x="carat", y=after_stat("count")))
    + geom_histogram(binwidth=0.5)
    + scale_y_sqrt()  # square root scale
)

# %%
(
    ggplot(diamonds, aes(x="carat", y=after_stat("count")))
    + geom_histogram(binwidth=0.5)
    + scale_y_log10()  # log scale
)
# Out:
# /Users/hassan/scm/python/plotnine/.venv/lib/python3.13/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log10

# %% [markdown]
# Change the look of your plot:

# %%
(
    ggplot(diamonds, aes(x="carat", y=after_stat("density")))
    + geom_histogram(
        binwidth=0.5,
        fill="green",  # change the fill colour (one colour)
        colour="pink",  # change the outline
        size=2,  # change the thickness of the outline
        alpha=0.7,  # change the transparency
    )
    + theme_xkcd()  # play with themes (look/arrangement)
)

# %% [markdown]
# Another change, this time changing the fill colours manually:

# %%
(
    ggplot(
        diamonds,
        aes(
            x="carat",
            y=after_stat("density"),
            fill="cut",  # change the fill colour using another variable
        ),
    )
    + scale_fill_manual(
        values=["#000000", "#E69F00", "#56B4E9", "#009E73", "#F0E442"]
    )  # change the fill colour
    + geom_histogram(
        binwidth=0.5,
        colour="#D55E00",  # change the outline
        size=1,  # change the thickness of the outline
        alpha=0.7,  # change the transparency
    )
    + theme_bw()  # play with themes (look/arrangement)
)

# %% [markdown]
# When faceting histograms with scaled counts/densities, they are
# normalised by each facet, and not overall. Here’s an example of a facet
# wrap:

# %%
(
    ggplot(diamonds, aes(x="carat", y=after_stat("ncount")))
    + geom_histogram(binwidth=0.5)
    + facet_wrap("color")  # facet wrap
)

# %% [markdown]
# Here’s an example of a facet grid with the count normalised in each
# grid:

# %%
(
    ggplot(diamonds, aes(x="carat", y=after_stat("ncount")))
    + geom_histogram(binwidth=0.5)
    + facet_grid("cut", "color")
)
